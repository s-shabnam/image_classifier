# %% [markdown]
# # Developing an AI application
#
# Going forward, AI algorithms will be incorporated into more and more everyday applications. For example, you might want to include an image classifier in a smart phone app. To do this, you'd use a deep learning model trained on hundreds of thousands of images as part of the overall application architecture. A large part of software development in the future will be using these types of models as common parts of applications.
#
# In this project, you'll train an image classifier to recognize different species of flowers. You can imagine using something like this in a phone app that tells you the name of the flower your camera is looking at. In practice you'd train this classifier, then export it for use in your application. We'll be using [this dataset](http://www.robots.ox.ac.uk/~vgg/data/flowers/102/index.html) of 102 flower categories, you can see a few examples below.
#
# <img src='assets/Flowers.png' width=500px>
#
# The project is broken down into multiple steps:
#
# * Load and preprocess the image dataset
# * Train the image classifier on your dataset
# * Use the trained classifier to predict image content
#
# We'll lead you through each part which you'll implement in Python.
#
# When you've completed this project, you'll have an application that can be trained on any set of labeled images. Here your network will be learning about flowers and end up as a command line application. But, what you do with your new skills depends on your imagination and effort in building a dataset. For example, imagine an app where you take a picture of a car, it tells you what the make and model is, then looks up information about it. Go build your own dataset and make something new.
#
# First up is importing the packages you'll need. It's good practice to keep all the imports at the beginning of your code. As you work through this notebook and find you need to import a package, make sure to add the import up here.
#
# Please make sure if you are running this notebook in the workspace that you have chosen GPU rather than CPU mode.

# %%
# Imports here
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import numpy as np
import json
import torch
from torch import nn
from torch import optim
import torch.nn.functional as F
from torchvision import datasets, transforms, models
from PIL import Image
import matplotlib.pyplot as plt
from workspace_utils import active_session

# %% [markdown]
# ## Load the data
#
# Here you'll use `torchvision` to load the data ([documentation](http://pytorch.org/docs/0.3.0/torchvision/index.html)). The data should be included alongside this notebook, otherwise you can [download it here](https://s3.amazonaws.com/content.udacity-data.com/nd089/flower_data.tar.gz). The dataset is split into three parts, training, validation, and testing. For the training, you'll want to apply transformations such as random scaling, cropping, and flipping. This will help the network generalize leading to better performance. You'll also need to make sure the input data is resized to 224x224 pixels as required by the pre-trained networks.
#
# The validation and testing sets are used to measure the model's performance on data it hasn't seen yet. For this you don't want any scaling or rotation transformations, but you'll need to resize then crop the images to the appropriate size.
#
# The pre-trained networks you'll use were trained on the ImageNet dataset where each color channel was normalized separately. For all three sets you'll need to normalize the means and standard deviations of the images to what the network expects. For the means, it's `[0.485, 0.456, 0.406]` and for the standard deviations `[0.229, 0.224, 0.225]`, calculated from the ImageNet images.  These values will shift each color channel to be centered at 0 and range from -1 to 1.

# %%
data_dir = 'flowers'
train_dir = data_dir + '/train'
valid_dir = data_dir + '/valid'
test_dir = data_dir + '/test'

data_dirs = {'train' : train_dir,
             'valid' : valid_dir,
             'test' : test_dir
    
}

data_sets = ['train', 'valid', 'test']

# %%
# Hyper-parameters
image_size = 256
crop_size = 224
normalize_param_mean = [0.485, 0.456, 0.406]
normalize_param_std = [0.229, 0.224, 0.225]
input_size = 25088 
hidden_size_1 = 4096
hidden_size_2 = 1024
output_size = 102
dropout_ps = 0.2
epochs_nb = 10
batch_size = 64
learning_rate = 0.001

# %%
# TODO: Define your transforms for the training, validation, and testing sets

data_transforms = {
    'train': transforms.Compose([transforms.RandomRotation(30),
                                       transforms.RandomResizedCrop(crop_size),
                                       transforms.RandomHorizontalFlip(),
                                       transforms.ToTensor(),
                                       transforms.Normalize(normalize_param_mean, normalize_param_std)
    ]),
    'valid': transforms.Compose([transforms.Resize(image_size),
                                       transforms.CenterCrop(crop_size),
                                       transforms.ToTensor(),
                                       transforms.Normalize(normalize_param_mean, normalize_param_std)
    ]),
    'test': transforms.Compose([transforms.Resize(image_size),
                                       transforms.CenterCrop(crop_size),
                                       transforms.ToTensor(),
                                       transforms.Normalize(normalize_param_mean, normalize_param_std)
    ])
}


image_datasets = {data_set : datasets.ImageFolder(data_dirs[data_set], transform = data_transforms[data_set]) 
                      for data_set in data_sets } 

data_loaders = {data_set : torch.utils.data.DataLoader(image_datasets[data_set], batch_size = batch_size, shuffle = True)
                    for data_set in data_sets }

dataset_sizes = {data_set: len(image_datasets[data_set] )
                   for data_set in data_sets
}

# %% [markdown]
# ### Label mapping
#
# You'll also need to load in a mapping from category label to category name. You can find this in the file `cat_to_name.json`. It's a JSON object which you can read in with the [`json` module](https://docs.python.org/2/library/json.html). This will give you a dictionary mapping the integer encoded categories to the actual names of the flowers.

# %%
with open('cat_to_name.json', 'r') as f:
    cat_to_name = json.load(f)

# %% [markdown]
# # Building and training the classifier
#
# Now that the data is ready, it's time to build and train the classifier. As usual, you should use one of the pretrained models from `torchvision.models` to get the image features. Build and train a new feed-forward classifier using those features.
#
# We're going to leave this part up to you. Refer to [the rubric](https://review.udacity.com/#!/rubrics/1663/view) for guidance on successfully completing this section. Things you'll need to do:
#
# * Load a [pre-trained network](http://pytorch.org/docs/master/torchvision/models.html) (If you need a starting point, the VGG networks work great and are straightforward to use)
# * Define a new, untrained feed-forward network as a classifier, using ReLU activations and dropout
# * Train the classifier layers using backpropagation using the pre-trained network to get the features
# * Track the loss and accuracy on the validation set to determine the best hyperparameters
#
# We've left a cell open for you below, but use as many as you need. Our advice is to break the problem up into smaller parts you can run separately. Check that each part is doing what you expect, then move on to the next. You'll likely find that as you work through each part, you'll need to go back and modify your previous code. This is totally normal!
#
# When training make sure you're updating only the weights of the feed-forward network. You should be able to get the validation accuracy above 70% if you build everything right. Make sure to try different hyperparameters (learning rate, units in the classifier, epochs, etc) to find the best model. Save those hyperparameters to use as default values in the next part of the project.
#
# One last important tip if you're using the workspace to run your code: To avoid having your workspace disconnect during the long-running tasks in this notebook, please read in the earlier page in this lesson called Intro to GPU Workspaces about Keeping Your Session Active. You'll want to include code from the workspace_utils.py module.

# %%
# Load pretrained network
model = models.vgg19(pretrained = True)
# Out:
# Downloading: "https://download.pytorch.org/models/vgg19-dcbb9e9d.pth" to /root/.torch/models/vgg19-dcbb9e9d.pth
# 100%|██████████| 574673361/574673361 [00:34<00:00, 16834433.02it/s]

# %%
#Define a new, untrained feed-forward network as a classifier,
class Classifier(nn.Module):
    def __init__(self):
        super().__init__()
        self.fc1 = nn.Linear(input_size, hidden_size_1)
        self.fc2 = nn.Linear(hidden_size_1, hidden_size_2)
        self.fc3 = nn.Linear(hidden_size_2, output_size)

        # Dropout module with drop probability
        self.dropout = nn.Dropout(p = dropout_ps)

    def forward(self, x):
        # make sure input tensor is flattened
        x = x.view(x.shape[0], -1)

        # Now with dropout
        x = self.dropout(F.relu(self.fc1(x)))      
        x = self.dropout(F.relu(self.fc2(x))) 
        # output so no dropout here
        x = F.log_softmax(self.fc3(x), dim=1)

        return x

# %%
# Use GPU if it's available
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %%
# Freeze model parameters
for param in model.parameters():
    param.requires_grad = False

# Add rhe new classifier
model.classifier = Classifier()

# Prepare training of the classifier layer
criterion = nn.NLLLoss()
optimizer = optim.Adam(model.classifier.parameters(), lr = learning_rate)

model.to(device);

# %%
def train_model(model, criterion, optimizer, epochs_nb = 10, device = 'cuda'):

    with active_session():
        steps = 0
        running_loss = 0
        print_every = 5
        for epoch in range(epochs_nb):
            for inputs, labels in  data_loaders['train']:
                steps += 1
                # Move input and label tensors to the default device
                inputs, labels = inputs.to(device), labels.to(device)

                optimizer.zero_grad()

                logps = model.forward(inputs)
                loss = criterion(logps, labels)
                loss.backward()
                optimizer.step()

                running_loss += loss.item()

                if steps % print_every == 0:
                    valid_loss = 0
                    accuracy = 0
                    model.eval()
                    with torch.no_grad():
                        for inputs, labels in data_loaders['valid']:
                            inputs, labels = inputs.to(device), labels.to(device)
                            logps = model.forward(inputs)
                            batch_loss = criterion(logps, labels)

                            valid_loss += batch_loss.item()

                            # Calculate accuracy
                            ps = torch.exp(logps)
                            top_p, top_class = ps.topk(1, dim=1)
                            equals = top_class == labels.view(*top_class.shape)
                            accuracy += torch.mean(equals.type(torch.FloatTensor)).item()

                    print(f"Epoch {epoch+1}/{epochs_nb}.. "
                          f"Step {steps}.. "
                          f"Train loss: {running_loss/print_every:.3f}.. "
                          f"Valid loss: {valid_loss/len(data_loaders['valid']):.3f}.. "
                          f"Valid accuracy: {accuracy/len(data_loaders['valid']):.3f}")
                    running_loss = 0
                    model.train()

# %%
train_model (model, criterion,optimizer, epochs_nb, device)
# Out:
# Epoch 1/10.. Step 5.. Train loss: 6.147.. Valid loss: 5.110.. Valid accuracy: 0.052
# Epoch 1/10.. Step 10.. Train loss: 4.790.. Valid loss: 4.506.. Valid accuracy: 0.043
# Epoch 1/10.. Step 15.. Train loss: 4.461.. Valid loss: 4.346.. Valid accuracy: 0.051
# Epoch 1/10.. Step 20.. Train loss: 4.322.. Valid loss: 4.077.. Valid accuracy: 0.150
# Epoch 1/10.. Step 25.. Train loss: 4.142.. Valid loss: 3.840.. Valid accuracy: 0.159
# Epoch 1/10.. Step 30.. Train loss: 3.938.. Valid loss: 3.502.. Valid accuracy: 0.219
# Epoch 1/10.. Step 35.. Train loss: 3.640.. Valid loss: 3.285.. Valid accuracy: 0.239
# Epoch 1/10.. Step 40.. Train loss: 3.368.. Valid loss: 2.886.. Valid accuracy: 0.330
# Epoch 1/10.. Step 45.. Train loss: 3.302.. Valid loss: 2.683.. Valid accuracy: 0.368
# Epoch 1/10.. Step 50.. Train loss: 3.039.. Valid loss: 2.426.. Valid accuracy: 0.415
# Epoch 1/10.. Step 55.. Train loss: 2.736.. Valid loss: 2.252.. Valid accuracy: 0.434
# Epoch 1/10.. Step 60.. Train loss: 2.570.. Valid loss: 2.048.. Valid accuracy: 0.480
# Epoch 1/10.. Step 65.. Train loss: 2.588.. Valid loss: 1.904.. Valid accuracy: 0.522
# Epoch 1/10.. Step 70.. Train loss: 2.300.. Valid loss: 1.797.. Valid accuracy: 0.532
# Epoch 1/10.. Step 75.. Train loss: 2.155.. Valid loss: 1.646.. Valid accuracy: 0.564
# Epoch 1/10.. Step 80.. Train loss: 1.983.. Valid loss: 1.512.. Valid accuracy: 0.587
# Epoch 1/10.. Step 85.. Train loss: 1.979.. Valid loss: 1.603.. Valid accuracy: 0.567
# Epoch 1/10.. Step 90.. Train loss: 1.863.. Valid loss: 1.434.. Valid accuracy: 0.606
# Epoch 1/10.. Step 95.. Train loss: 2.036.. Valid loss: 1.416.. Valid accuracy: 0.611
# Epoch 1/10.. Step 100.. Train loss: 1.974.. Valid loss: 1.374.. Valid accuracy: 0.630
# Epoch 2/10.. Step 105.. Train loss: 1.818.. Valid loss: 1.408.. Valid accuracy: 0.600
# Epoch 2/10.. Step 110.. Train loss: 1.665.. Valid loss: 1.315.. Valid accuracy: 0.624
# Epoch 2/10.. Step 115.. Train loss: 1.782.. Valid loss: 1.133.. Valid accuracy: 0.709
# Epoch 2/10.. Step 120.. Train loss: 1.612.. Valid loss: 1.107.. Valid accuracy: 0.709
# Epoch 2/10.. Step 125.. Train loss: 1.640.. Valid loss: 1.252.. Valid accuracy: 0.663
# Epoch 2/10.. Step 130.. Train loss: 1.556.. Valid loss: 1.163.. Valid accuracy: 0.685
# Epoch 2/10.. Step 135.. Train loss: 1.741.. Valid loss: 1.087.. Valid accuracy: 0.696
# Epoch 2/10.. Step 140.. Train loss: 1.508.. Valid loss: 1.070.. Valid accuracy: 0.721
# Epoch 2/10.. Step 145.. Train loss: 1.709.. Valid loss: 1.036.. Valid accuracy: 0.703
# Epoch 2/10.. Step 150.. Train loss: 1.525.. Valid loss: 0.994.. Valid accuracy: 0.706
# Epoch 2/10.. Step 155.. Train loss: 1.350.. Valid loss: 0.932.. Valid accuracy: 0.751
# Epoch 2/10.. Step 160.. Train loss: 1.499.. Valid loss: 0.919.. Valid accuracy: 0.734
# Epoch 2/10.. Step 165.. Train loss: 1.465.. Valid loss: 0.879.. Valid accuracy: 0.763
# Epoch 2/10.. Step 170.. Train loss: 1.328.. Valid loss: 0.850.. Valid accuracy: 0.756
# Epoch 2/10.. Step 175.. Train loss: 1.440.. Valid loss: 0.867.. Valid accuracy: 0.759
# Epoch 2/10.. Step 180.. Train loss: 1.455.. Valid loss: 0.908.. Valid accuracy: 0.745
# Epoch 2/10.. Step 185.. Train loss: 1.303.. Valid loss: 0.942.. Valid accuracy: 0.737
# Epoch 2/10.. Step 190.. Train loss: 1.380.. Valid loss: 0.823.. Valid accuracy: 0.772
# Epoch 2/10.. Step 195.. Train loss: 1.177.. Valid loss: 0.797.. Valid accuracy: 0.795
# Epoch 2/10.. Step 200.. Train loss: 1.344.. Valid loss: 0.893.. Valid accuracy: 0.754
# Epoch 2/10.. Step 205.. Train loss: 1.290.. Valid loss: 0.828.. Valid accuracy: 0.777
# Epoch 3/10.. Step 210.. Train loss: 1.258.. Valid loss: 0.828.. Valid accuracy: 0.769
# Epoch 3/10.. Step 215.. Train loss: 1.270.. Valid loss: 0.800.. Valid accuracy: 0.765
# Epoch 3/10.. Step 220.. Train loss: 1.210.. Valid loss: 0.794.. Valid accuracy: 0.771
# Epoch 3/10.. Step 225.. Train loss: 1.285.. Valid loss: 0.750.. Valid accuracy: 0.785
# Epoch 3/10.. Step 230.. Train loss: 1.236.. Valid loss: 0.802.. Valid accuracy: 0.773
# Epoch 3/10.. Step 235.. Train loss: 1.176.. Valid loss: 0.770.. Valid accuracy: 0.777
# Epoch 3/10.. Step 240.. Train loss: 1.078.. Valid loss: 0.755.. Valid accuracy: 0.789
# Epoch 3/10.. Step 245.. Train loss: 1.324.. Valid loss: 0.776.. Valid accuracy: 0.778
# Epoch 3/10.. Step 250.. Train loss: 1.158.. Valid loss: 0.807.. Valid accuracy: 0.758
# Epoch 3/10.. Step 255.. Train loss: 1.136.. Valid loss: 0.749.. Valid accuracy: 0.784
# Epoch 3/10.. Step 260.. Train loss: 1.192.. Valid loss: 0.707.. Valid accuracy: 0.784
# Epoch 3/10.. Step 265.. Train loss: 1.095.. Valid loss: 0.771.. Valid accuracy: 0.797
# Epoch 3/10.. Step 270.. Train loss: 1.068.. Valid loss: 0.701.. Valid accuracy: 0.797
# Epoch 3/10.. Step 275.. Train loss: 1.093.. Valid loss: 0.727.. Valid accuracy: 0.785
# Epoch 3/10.. Step 280.. Train loss: 1.096.. Valid loss: 0.695.. Valid accuracy: 0.797
# Epoch 3/10.. Step 285.. Train loss: 1.155.. Valid loss: 0.668.. Valid accuracy: 0.803
# Epoch 3/10.. Step 290.. Train loss: 1.124.. Valid loss: 0.648.. Valid accuracy: 0.804
# Epoch 3/10.. Step 295.. Train loss: 1.049.. Valid loss: 0.667.. Valid accuracy: 0.813
# Epoch 3/10.. Step 300.. Train loss: 1.002.. Valid loss: 0.710.. Valid accuracy: 0.806
# Epoch 3/10.. Step 305.. Train loss: 1.164.. Valid loss: 0.724.. Valid accuracy: 0.801
# Epoch 4/10.. Step 310.. Train loss: 1.144.. Valid loss: 0.756.. Valid accuracy: 0.785
# Epoch 4/10.. Step 315.. Train loss: 1.101.. Valid loss: 0.671.. Valid accuracy: 0.804
# Epoch 4/10.. Step 320.. Train loss: 1.101.. Valid loss: 0.679.. Valid accuracy: 0.794
# Epoch 4/10.. Step 325.. Train loss: 1.153.. Valid loss: 0.628.. Valid accuracy: 0.825
# Epoch 4/10.. Step 330.. Train loss: 1.091.. Valid loss: 0.606.. Valid accuracy: 0.822
# Epoch 4/10.. Step 335.. Train loss: 1.045.. Valid loss: 0.637.. Valid accuracy: 0.819
# Epoch 4/10.. Step 340.. Train loss: 1.104.. Valid loss: 0.698.. Valid accuracy: 0.800
# Epoch 4/10.. Step 345.. Train loss: 1.036.. Valid loss: 0.644.. Valid accuracy: 0.814
# Epoch 4/10.. Step 350.. Train loss: 1.102.. Valid loss: 0.608.. Valid accuracy: 0.820
# Epoch 4/10.. Step 355.. Train loss: 1.087.. Valid loss: 0.593.. Valid accuracy: 0.825
# Epoch 4/10.. Step 360.. Train loss: 0.941.. Valid loss: 0.643.. Valid accuracy: 0.814
# Epoch 4/10.. Step 365.. Train loss: 1.032.. Valid loss: 0.598.. Valid accuracy: 0.831
# Epoch 4/10.. Step 370.. Train loss: 1.049.. Valid loss: 0.632.. Valid accuracy: 0.817
# Epoch 4/10.. Step 375.. Train loss: 0.960.. Valid loss: 0.629.. Valid accuracy: 0.819
# Epoch 4/10.. Step 380.. Train loss: 0.931.. Valid loss: 0.585.. Valid accuracy: 0.840
# Epoch 4/10.. Step 385.. Train loss: 1.050.. Valid loss: 0.595.. Valid accuracy: 0.828
# Epoch 4/10.. Step 390.. Train loss: 1.308.. Valid loss: 0.594.. Valid accuracy: 0.832
# Epoch 4/10.. Step 395.. Train loss: 0.898.. Valid loss: 0.660.. Valid accuracy: 0.818
# Epoch 4/10.. Step 400.. Train loss: 1.127.. Valid loss: 0.629.. Valid accuracy: 0.835
# Epoch 4/10.. Step 405.. Train loss: 1.006.. Valid loss: 0.588.. Valid accuracy: 0.844
# Epoch 4/10.. Step 410.. Train loss: 1.129.. Valid loss: 0.589.. Valid accuracy: 0.837
# Epoch 5/10.. Step 415.. Train loss: 0.858.. Valid loss: 0.616.. Valid accuracy: 0.833
# Epoch 5/10.. Step 420.. Train loss: 1.018.. Valid loss: 0.610.. Valid accuracy: 0.832
# Epoch 5/10.. Step 425.. Train loss: 0.962.. Valid loss: 0.574.. Valid accuracy: 0.842
# Epoch 5/10.. Step 430.. Train loss: 0.771.. Valid loss: 0.651.. Valid accuracy: 0.821
# Epoch 5/10.. Step 435.. Train loss: 0.865.. Valid loss: 0.605.. Valid accuracy: 0.838
# Epoch 5/10.. Step 440.. Train loss: 0.939.. Valid loss: 0.564.. Valid accuracy: 0.838
# Epoch 5/10.. Step 445.. Train loss: 0.905.. Valid loss: 0.558.. Valid accuracy: 0.843
# Epoch 5/10.. Step 450.. Train loss: 0.774.. Valid loss: 0.580.. Valid accuracy: 0.845
# Epoch 5/10.. Step 455.. Train loss: 0.935.. Valid loss: 0.537.. Valid accuracy: 0.859
# Epoch 5/10.. Step 460.. Train loss: 0.943.. Valid loss: 0.557.. Valid accuracy: 0.838
# Epoch 5/10.. Step 465.. Train loss: 0.960.. Valid loss: 0.562.. Valid accuracy: 0.846
# Epoch 5/10.. Step 470.. Train loss: 0.828.. Valid loss: 0.517.. Valid accuracy: 0.857
# Epoch 5/10.. Step 475.. Train loss: 1.023.. Valid loss: 0.542.. Valid accuracy: 0.843
# Epoch 5/10.. Step 480.. Train loss: 0.901.. Valid loss: 0.521.. Valid accuracy: 0.855
# Epoch 5/10.. Step 485.. Train loss: 0.935.. Valid loss: 0.509.. Valid accuracy: 0.858
# Epoch 5/10.. Step 490.. Train loss: 0.954.. Valid loss: 0.543.. Valid accuracy: 0.845
# Epoch 5/10.. Step 495.. Train loss: 0.804.. Valid loss: 0.569.. Valid accuracy: 0.835
# Epoch 5/10.. Step 500.. Train loss: 0.929.. Valid loss: 0.624.. Valid accuracy: 0.826
# Epoch 5/10.. Step 505.. Train loss: 1.139.. Valid loss: 0.612.. Valid accuracy: 0.836
# Epoch 5/10.. Step 510.. Train loss: 0.898.. Valid loss: 0.528.. Valid accuracy: 0.845
# Epoch 5/10.. Step 515.. Train loss: 0.964.. Valid loss: 0.577.. Valid accuracy: 0.843
# Epoch 6/10.. Step 520.. Train loss: 0.806.. Valid loss: 0.596.. Valid accuracy: 0.830
# Epoch 6/10.. Step 525.. Train loss: 0.873.. Valid loss: 0.586.. Valid accuracy: 0.827
# Epoch 6/10.. Step 530.. Train loss: 0.878.. Valid loss: 0.562.. Valid accuracy: 0.846
# Epoch 6/10.. Step 535.. Train loss: 0.788.. Valid loss: 0.567.. Valid accuracy: 0.832
# Epoch 6/10.. Step 540.. Train loss: 0.848.. Valid loss: 0.557.. Valid accuracy: 0.835
# Epoch 6/10.. Step 545.. Train loss: 0.801.. Valid loss: 0.632.. Valid accuracy: 0.827
# Epoch 6/10.. Step 550.. Train loss: 0.991.. Valid loss: 0.569.. Valid accuracy: 0.841
# Epoch 6/10.. Step 555.. Train loss: 0.947.. Valid loss: 0.573.. Valid accuracy: 0.830
# Epoch 6/10.. Step 560.. Train loss: 1.130.. Valid loss: 0.557.. Valid accuracy: 0.831
# Epoch 6/10.. Step 565.. Train loss: 0.864.. Valid loss: 0.586.. Valid accuracy: 0.823
# Epoch 6/10.. Step 570.. Train loss: 0.877.. Valid loss: 0.549.. Valid accuracy: 0.833
# Epoch 6/10.. Step 575.. Train loss: 0.846.. Valid loss: 0.532.. Valid accuracy: 0.843
# Epoch 6/10.. Step 580.. Train loss: 0.861.. Valid loss: 0.504.. Valid accuracy: 0.851
# Epoch 6/10.. Step 585.. Train loss: 0.906.. Valid loss: 0.523.. Valid accuracy: 0.848
# Epoch 6/10.. Step 590.. Train loss: 0.981.. Valid loss: 0.582.. Valid accuracy: 0.829
# Epoch 6/10.. Step 595.. Train loss: 0.905.. Valid loss: 0.528.. Valid accuracy: 0.854
# Epoch 6/10.. Step 600.. Train loss: 1.036.. Valid loss: 0.563.. Valid accuracy: 0.833
# Epoch 6/10.. Step 605.. Train loss: 1.034.. Valid loss: 0.562.. Valid accuracy: 0.840
# Epoch 6/10.. Step 610.. Train loss: 0.745.. Valid loss: 0.576.. Valid accuracy: 0.840
# Epoch 6/10.. Step 615.. Train loss: 0.968.. Valid loss: 0.544.. Valid accuracy: 0.848
# Epoch 7/10.. Step 620.. Train loss: 0.925.. Valid loss: 0.536.. Valid accuracy: 0.845
# Epoch 7/10.. Step 625.. Train loss: 0.790.. Valid loss: 0.562.. Valid accuracy: 0.835
# Epoch 7/10.. Step 630.. Train loss: 0.874.. Valid loss: 0.571.. Valid accuracy: 0.833
# Epoch 7/10.. Step 635.. Train loss: 1.027.. Valid loss: 0.566.. Valid accuracy: 0.831
# Epoch 7/10.. Step 640.. Train loss: 0.735.. Valid loss: 0.524.. Valid accuracy: 0.848
# Epoch 7/10.. Step 645.. Train loss: 0.752.. Valid loss: 0.478.. Valid accuracy: 0.856
# Epoch 7/10.. Step 650.. Train loss: 0.821.. Valid loss: 0.504.. Valid accuracy: 0.847
# Epoch 7/10.. Step 655.. Train loss: 0.830.. Valid loss: 0.512.. Valid accuracy: 0.849
# Epoch 7/10.. Step 660.. Train loss: 1.017.. Valid loss: 0.570.. Valid accuracy: 0.838
# Epoch 7/10.. Step 665.. Train loss: 0.958.. Valid loss: 0.492.. Valid accuracy: 0.867
# Epoch 7/10.. Step 670.. Train loss: 0.882.. Valid loss: 0.486.. Valid accuracy: 0.857
# Epoch 7/10.. Step 675.. Train loss: 0.723.. Valid loss: 0.511.. Valid accuracy: 0.858
# Epoch 7/10.. Step 680.. Train loss: 0.901.. Valid loss: 0.493.. Valid accuracy: 0.864
# Epoch 7/10.. Step 685.. Train loss: 0.860.. Valid loss: 0.506.. Valid accuracy: 0.857
# Epoch 7/10.. Step 690.. Train loss: 0.708.. Valid loss: 0.541.. Valid accuracy: 0.844
# Epoch 7/10.. Step 695.. Train loss: 0.938.. Valid loss: 0.541.. Valid accuracy: 0.849
# Epoch 7/10.. Step 700.. Train loss: 0.840.. Valid loss: 0.494.. Valid accuracy: 0.857
# Epoch 7/10.. Step 705.. Train loss: 0.879.. Valid loss: 0.493.. Valid accuracy: 0.861
# Epoch 7/10.. Step 710.. Train loss: 0.827.. Valid loss: 0.517.. Valid accuracy: 0.855
# Epoch 7/10.. Step 715.. Train loss: 0.810.. Valid loss: 0.506.. Valid accuracy: 0.849
# Epoch 7/10.. Step 720.. Train loss: 0.785.. Valid loss: 0.487.. Valid accuracy: 0.861
# Epoch 8/10.. Step 725.. Train loss: 0.923.. Valid loss: 0.512.. Valid accuracy: 0.849
# Epoch 8/10.. Step 730.. Train loss: 0.771.. Valid loss: 0.525.. Valid accuracy: 0.842
# Epoch 8/10.. Step 735.. Train loss: 0.824.. Valid loss: 0.528.. Valid accuracy: 0.850
# Epoch 8/10.. Step 740.. Train loss: 0.877.. Valid loss: 0.511.. Valid accuracy: 0.861
# Epoch 8/10.. Step 745.. Train loss: 0.892.. Valid loss: 0.508.. Valid accuracy: 0.861
# Epoch 8/10.. Step 750.. Train loss: 0.704.. Valid loss: 0.538.. Valid accuracy: 0.859
# Epoch 8/10.. Step 755.. Train loss: 0.713.. Valid loss: 0.535.. Valid accuracy: 0.865
# Epoch 8/10.. Step 760.. Train loss: 0.917.. Valid loss: 0.503.. Valid accuracy: 0.859
# Epoch 8/10.. Step 765.. Train loss: 0.796.. Valid loss: 0.503.. Valid accuracy: 0.859
# Epoch 8/10.. Step 770.. Train loss: 0.776.. Valid loss: 0.524.. Valid accuracy: 0.856
# Epoch 8/10.. Step 775.. Train loss: 0.934.. Valid loss: 0.544.. Valid accuracy: 0.837
# Epoch 8/10.. Step 780.. Train loss: 0.880.. Valid loss: 0.555.. Valid accuracy: 0.842
# Epoch 8/10.. Step 785.. Train loss: 0.754.. Valid loss: 0.591.. Valid accuracy: 0.837
# Epoch 8/10.. Step 790.. Train loss: 0.861.. Valid loss: 0.575.. Valid accuracy: 0.835
# Epoch 8/10.. Step 795.. Train loss: 0.874.. Valid loss: 0.496.. Valid accuracy: 0.852
# Epoch 8/10.. Step 800.. Train loss: 0.832.. Valid loss: 0.479.. Valid accuracy: 0.867
# Epoch 8/10.. Step 805.. Train loss: 0.888.. Valid loss: 0.452.. Valid accuracy: 0.878
# Epoch 8/10.. Step 810.. Train loss: 0.918.. Valid loss: 0.472.. Valid accuracy: 0.872
# Epoch 8/10.. Step 815.. Train loss: 0.795.. Valid loss: 0.482.. Valid accuracy: 0.857
# Epoch 8/10.. Step 820.. Train loss: 0.954.. Valid loss: 0.527.. Valid accuracy: 0.854
# Epoch 9/10.. Step 825.. Train loss: 0.741.. Valid loss: 0.505.. Valid accuracy: 0.854
# Epoch 9/10.. Step 830.. Train loss: 0.916.. Valid loss: 0.516.. Valid accuracy: 0.862
# Epoch 9/10.. Step 835.. Train loss: 0.873.. Valid loss: 0.495.. Valid accuracy: 0.867
# Epoch 9/10.. Step 840.. Train loss: 0.650.. Valid loss: 0.492.. Valid accuracy: 0.865
# Epoch 9/10.. Step 845.. Train loss: 0.737.. Valid loss: 0.491.. Valid accuracy: 0.862
# Epoch 9/10.. Step 850.. Train loss: 0.720.. Valid loss: 0.508.. Valid accuracy: 0.860
# Epoch 9/10.. Step 855.. Train loss: 0.758.. Valid loss: 0.537.. Valid accuracy: 0.861
# Epoch 9/10.. Step 860.. Train loss: 0.825.. Valid loss: 0.494.. Valid accuracy: 0.870
# Epoch 9/10.. Step 865.. Train loss: 0.653.. Valid loss: 0.463.. Valid accuracy: 0.868
# Epoch 9/10.. Step 870.. Train loss: 0.780.. Valid loss: 0.450.. Valid accuracy: 0.874
# Epoch 9/10.. Step 875.. Train loss: 0.989.. Valid loss: 0.472.. Valid accuracy: 0.873
# Epoch 9/10.. Step 880.. Train loss: 0.750.. Valid loss: 0.433.. Valid accuracy: 0.876
# Epoch 9/10.. Step 885.. Train loss: 0.670.. Valid loss: 0.436.. Valid accuracy: 0.881
# Epoch 9/10.. Step 890.. Train loss: 0.778.. Valid loss: 0.486.. Valid accuracy: 0.865
# Epoch 9/10.. Step 895.. Train loss: 0.649.. Valid loss: 0.506.. Valid accuracy: 0.866
# Epoch 9/10.. Step 900.. Train loss: 0.709.. Valid loss: 0.491.. Valid accuracy: 0.864
# Epoch 9/10.. Step 905.. Train loss: 0.673.. Valid loss: 0.487.. Valid accuracy: 0.862
# Epoch 9/10.. Step 910.. Train loss: 0.761.. Valid loss: 0.459.. Valid accuracy: 0.883
# Epoch 9/10.. Step 915.. Train loss: 0.826.. Valid loss: 0.426.. Valid accuracy: 0.892
# Epoch 9/10.. Step 920.. Train loss: 0.689.. Valid loss: 0.498.. Valid accuracy: 0.863
# Epoch 9/10.. Step 925.. Train loss: 0.909.. Valid loss: 0.478.. Valid accuracy: 0.869
# Epoch 10/10.. Step 930.. Train loss: 0.764.. Valid loss: 0.452.. Valid accuracy: 0.876
# Epoch 10/10.. Step 935.. Train loss: 0.733.. Valid loss: 0.458.. Valid accuracy: 0.884
# Epoch 10/10.. Step 940.. Train loss: 0.595.. Valid loss: 0.473.. Valid accuracy: 0.885
# Epoch 10/10.. Step 945.. Train loss: 0.833.. Valid loss: 0.502.. Valid accuracy: 0.875
# Epoch 10/10.. Step 950.. Train loss: 0.741.. Valid loss: 0.486.. Valid accuracy: 0.867
# Epoch 10/10.. Step 955.. Train loss: 0.708.. Valid loss: 0.480.. Valid accuracy: 0.863
# Epoch 10/10.. Step 960.. Train loss: 0.837.. Valid loss: 0.458.. Valid accuracy: 0.870
# Epoch 10/10.. Step 965.. Train loss: 0.700.. Valid loss: 0.437.. Valid accuracy: 0.873
# Epoch 10/10.. Step 970.. Train loss: 0.737.. Valid loss: 0.447.. Valid accuracy: 0.872
# Epoch 10/10.. Step 975.. Train loss: 0.699.. Valid loss: 0.470.. Valid accuracy: 0.856
# Epoch 10/10.. Step 980.. Train loss: 0.817.. Valid loss: 0.467.. Valid accuracy: 0.860
# Epoch 10/10.. Step 985.. Train loss: 0.707.. Valid loss: 0.451.. Valid accuracy: 0.878
# Epoch 10/10.. Step 990.. Train loss: 0.886.. Valid loss: 0.472.. Valid accuracy: 0.876
# Epoch 10/10.. Step 995.. Train loss: 0.966.. Valid loss: 0.449.. Valid accuracy: 0.876
# Epoch 10/10.. Step 1000.. Train loss: 0.751.. Valid loss: 0.464.. Valid accuracy: 0.866
# Epoch 10/10.. Step 1005.. Train loss: 0.697.. Valid loss: 0.462.. Valid accuracy: 0.872
# Epoch 10/10.. Step 1010.. Train loss: 0.759.. Valid loss: 0.463.. Valid accuracy: 0.877
# Epoch 10/10.. Step 1015.. Train loss: 0.824.. Valid loss: 0.405.. Valid accuracy: 0.898
# Epoch 10/10.. Step 1020.. Train loss: 0.957.. Valid loss: 0.419.. Valid accuracy: 0.889
# Epoch 10/10.. Step 1025.. Train loss: 0.926.. Valid loss: 0.437.. Valid accuracy: 0.879
# Epoch 10/10.. Step 1030.. Train loss: 0.739.. Valid loss: 0.470.. Valid accuracy: 0.874

# %% [markdown]
# ## Testing your network
#
# It's good practice to test your trained network on test data, images the network has never seen either in training or validation. This will give you a good estimate for the model's performance on completely new images. Run the test images through the network and measure the accuracy, the same way you did validation. You should be able to reach around 70% accuracy on the test set if the model has been trained well.

# %%
# TODO: Do validation on the test set

def check_accuracy(model, data_loader, device = 'cuda'):  
    model.eval()
    model.to(device)
    accuracy = 0
    with torch.no_grad():
        for inputs, labels in data_loader:
            inputs, labels = inputs.to(device), labels.to(device)
            output = model.forward(inputs)
            
            # Calculate accuracy
            top_p, top_class = output.topk(1, dim=1)
            prob = torch.exp(top_p)
            equals = top_class == labels.view(*top_class.shape)
            accuracy += torch.mean(equals.type(torch.FloatTensor)).item()
                
        print(f"Accuracy of the network on the {len(data_loader):.3f}"
          " images: %d %%" % (100 * accuracy/len(data_loader)))

# %%
check_accuracy(model, data_loaders['test'], device)
# Out:
# Accuracy of the network on the 13.000 images: 86 %

# %% [markdown]
# ## Save the checkpoint
#
# Now that your network is trained, save the model so you can load it later for making predictions. You probably want to save other things such as the mapping of classes to indices which you get from one of the image datasets: `image_datasets['train'].class_to_idx`. You can attach this to the model as an attribute which makes inference easier later on.
#
# ```model.class_to_idx = image_datasets['train'].class_to_idx```
#
# Remember that you'll want to completely rebuild the model later so you can use it for inference. Make sure to include any information you need in the checkpoint. If you want to load the model and keep training, you'll want to save the number of epochs as well as the optimizer state, `optimizer.state_dict`. You'll likely want to use this trained model in the next part of the project, so best to save it now.

# %%
# TODO: Save the checkpoint 
def save_model_to_checkpoint(path):
    model.class_to_idx = image_datasets['train'].class_to_idx
    model.cpu()
    checkpoint = {'model_arch': 'vgg19',
                  'class_to_idx' : model.class_to_idx,
                  'state_dict': model.state_dict()}
    torch.save(checkpoint, path)

# %%
save_model_to_checkpoint('checkpoint.pth')

# %% [markdown]
# ## Loading the checkpoint
#
# At this point it's good to write a function that can load a checkpoint and rebuild the model. That way you can come back to this project and keep working on it without having to retrain the network.

# %%
# TODO: Write a function that loads a checkpoint and rebuilds the model

def load_model_from_checkpoint(filepath):
    checkpoint = torch.load(filepath)
    if checkpoint['model_arch'] == 'vgg19':
        model = models.vgg19(pretrained = True)
        for param in model.parameters():
            param.requires_grad = False
    else:
        print('The models architecture is not recognized')
        
    model.class_to_idx = checkpoint['class_to_idx']
    
    model.classifier = Classifier()
    model.load_state_dict(checkpoint['state_dict'])
    return model

# %%
new_model = load_model_from_checkpoint('checkpoint.pth')
check_accuracy(new_model, data_loaders['test'], device)
# Out:
# Accuracy of the network on the 13.000 images: 85 %

# %% [markdown]
# # Inference for classification
#
# Now you'll write a function to use a trained network for inference. That is, you'll pass an image into the network and predict the class of the flower in the image. Write a function called `predict` that takes an image and a model, then returns the top $K$ most likely classes along with the probabilities. It should look like
#
# ```python
# probs, classes = predict(image_path, model)
# print(probs)
# print(classes)
# > [ 0.01558163  0.01541934  0.01452626  0.01443549  0.01407339]
# > ['70', '3', '45', '62', '55']
# ```
#
# First you'll need to handle processing the input image such that it can be used in your network.
#
# ## Image Preprocessing
#
# You'll want to use `PIL` to load the image ([documentation](https://pillow.readthedocs.io/en/latest/reference/Image.html)). It's best to write a function that preprocesses the image so it can be used as input for the model. This function should process the images in the same manner used for training.
#
# First, resize the images where the shortest side is 256 pixels, keeping the aspect ratio. This can be done with the [`thumbnail`](http://pillow.readthedocs.io/en/3.1.x/reference/Image.html#PIL.Image.Image.thumbnail) or [`resize`](http://pillow.readthedocs.io/en/3.1.x/reference/Image.html#PIL.Image.Image.thumbnail) methods. Then you'll need to crop out the center 224x224 portion of the image.
#
# Color channels of images are typically encoded as integers 0-255, but the model expected floats 0-1. You'll need to convert the values. It's easiest with a Numpy array, which you can get from a PIL image like so `np_image = np.array(pil_image)`.
#
# As before, the network expects the images to be normalized in a specific way. For the means, it's `[0.485, 0.456, 0.406]` and for the standard deviations `[0.229, 0.224, 0.225]`. You'll want to subtract the means from each color channel, then divide by the standard deviation.
#
# And finally, PyTorch expects the color channel to be the first dimension but it's the third dimension in the PIL image and Numpy array. You can reorder dimensions using [`ndarray.transpose`](https://docs.scipy.org/doc/numpy-1.13.0/reference/generated/numpy.ndarray.transpose.html). The color channel needs to be first and retain the order of the other two dimensions.

# %%
def process_image(image_path):
    ''' Scales, crops, and normalizes a PIL image for a PyTorch model,
        returns an Numpy array
    '''
    
    # scale
    imageL = Image.open(image_path)
    image_width = imageL.size[0]
    image_height = imageL.size[1]
    
    if image_width > image_height : # width > height
        imageL.thumbnail((100000, image_size))
    else:
        imageL.thumbnail((image_size, 100000))
    
    # crop
    left_margin = (image_width - crop_size)/2
    bottom_margin = (image_height - crop_size)/2
    right_margin = left_margin + crop_size
    top_margin = bottom_margin + crop_size
    center_box = (left_margin, bottom_margin, right_margin,    
                   top_margin)
    
    imageL.crop(center_box)
    
    # normalize
    np_image = np.array(imageL)/255
    
    mean = np.array(normalize_param_mean)
    std = np.array(normalize_param_std)
    np_image = (np_image - mean)/std
    tronsposed_image = np_image.transpose((2, 0, 1))
    return tronsposed_image

# %% [markdown]
# To check your work, the function below converts a PyTorch tensor and displays it in the notebook. If your `process_image` function works, running the output through this function should return the original image (except for the cropped out portions).

# %%
def imshow(image, ax=None, title=None):
    if ax is None:
        fig, ax = plt.subplots()
    
    # PyTorch tensors assume the color channel is the first dimension
    # but matplotlib assumes is the third dimension
    image = image.transpose((1, 2, 0))
    
    # Undo preprocessing
    mean = np.array([0.485, 0.456, 0.406])
    std = np.array([0.229, 0.224, 0.225])
    image = std * image + mean
    
    # Image needs to be clipped between 0 and 1 or it looks like noise when displayed
    image = np.clip(image, 0, 1)
    
    ax.imshow(image)
    
    return ax

# %%
image_path = 'flowers/test/1/image_06743.jpg'
img = process_image(image_path)
imshow(img)

# %% [markdown]
# ## Class Prediction
#
# Once you can get images in the correct format, it's time to write a function for making predictions with your model. A common practice is to predict the top 5 or so (usually called top-$K$) most probable classes. You'll want to calculate the class probabilities then find the $K$ largest values.
#
# To get the top $K$ largest values in a tensor use [`x.topk(k)`](http://pytorch.org/docs/master/torch.html#torch.topk). This method returns both the highest `k` probabilities and the indices of those probabilities corresponding to the classes. You need to convert from these indices to the actual class labels using `class_to_idx` which hopefully you added to the model or from an `ImageFolder` you used to load the data ([see here](#Save-the-checkpoint)). Make sure to invert the dictionary so you get a mapping from index to class as well.
#
# Again, this method should take a path to an image and a model checkpoint, then return the probabilities and classes.
#
# ```python
# probs, classes = predict(image_path, model)
# print(probs)
# print(classes)
# > [ 0.01558163  0.01541934  0.01452626  0.01443549  0.01407339]
# > ['70', '3', '45', '62', '55']
# ```

# %%
def predict(image_path, model, topk=5):
    ''' Predict the class (or classes) of an image using a trained deep learning model. '''
    # process image
    model.cpu()
    image = process_image(image_path)

    # convert to tensor
    image_tensor = torch.from_numpy(image).type(torch.FloatTensor)
    image_tensor.resize_([1, 3, crop_size, crop_size])

    #do prediction
    prediction = torch.exp(model(image_tensor))
    probabilities, predicted_labels = prediction.topk(topk)

    probabilities = probabilities.detach().numpy().tolist()[0]
    predicted_labels = predicted_labels.detach().numpy().tolist()[0]

    # get classes
    idx_to_class = {val: key for key, val in
                                     model.class_to_idx.items()}
    predicted_classes = [idx_to_class[label] for label in predicted_labels]
    predicted_class_labels = [cat_to_name[classes] for classes in predicted_classes]
    return probabilities, predicted_class_labels

# %%
image_path = 'flowers/test/1/image_06754.jpg'

predict(image_path, new_model)
# Out:
# ([0.39440324902534485,
#   0.0943770632147789,
#   0.09355781972408295,
#   0.08962614834308624,
#   0.0489492192864418],
#  ["colt's foot",
#   'barbeton daisy',
#   'buttercup',
#   'common dandelion',
#   'sunflower'])

# %% [markdown]
# ## Sanity Checking
#
# Now that you can use a trained model for predictions, check to make sure it makes sense. Even if the testing accuracy is high, it's always good to check that there aren't obvious bugs. Use `matplotlib` to plot the probabilities for the top 5 classes as a bar graph, along with the input image. It should look like this:
#
# <img src='assets/inference_example.png' width=300px>
#
# You can convert from the class integer encoding to actual flower names with the `cat_to_name.json` file (should have been loaded earlier in the notebook). To show a PyTorch tensor as an image, use the `imshow` function defined above.

# %%
# TODO: Display an image along with the top 5 classes

def view_classifier(image_path, model):
    # Set up plot
    plt.figure(figsize = (6,9))
    ax = plt.subplot(2,1,1)
    # Set up title
    flower_num = image_path.split('/')[2]
    title = cat_to_name[flower_num]
    # Plot flower
    img = process_image(image_path)
    imshow(img, ax, title = title);
    # Make prediction
    probilities, predicted_classes = predict(image_path, model) 
    
    # Plot bar chart
    fig, ax = plt.subplots()

    # Example data
    y_pos = np.arange(len(predicted_classes))

    ax.barh(y_pos, probilities, align='center')
    ax.set_yticks(y_pos)
    ax.set_yticklabels(predicted_classes)
    ax.invert_yaxis()  # labels read top-to-bottom
    ax.set_xlabel('Probability')
    #ax.set_ylabel('Classes')
    ax.set_title('Top 5 predictions')

    plt.show()

# %%
image_path = 'flowers/test/1/image_06754.jpg'

view_classifier(image_path, new_model)
